# %%
import math

# %% [markdown]
# Из колоды в 52 карты извлекаются случайным образом 4 карты.
# a) Найти вероятность того, что все карты – крести.
# б) Найти вероятность, что среди 4-х карт окажется ХОТЯ бы один туз.

# %%
#Поочередно извлекаем карты и перемноджаем вероятности
# в колоде из 52 карт 4 масти по 13 карт
#а)
P1 = (13/52) * (12/51) * (11/50) * (10/49)
print(f'Вероятность того, что все карты крести {round(P1*100,2)}%')
#б)
P2 = P1 * 4/48
print(f'Вероятность того, что среди 4-х карт окажется ХОТЯ бы один туз {round(P2*100,3)}%')
# Out:
# Вероятность того, что все карты крести 0.26%
# 0.00022008803521408565
# Вероятность того, что среди 4-х карт окажется ХОТЯ бы один туз 0.022%

# %%
На входной двери подъезда установлен кодовый замок, содержащий десять кнопок с цифрами от 0 до 9. 
Код содержит три цифры, которые нужно нажать одновременно. 
Какова вероятность того, что человек, не знающий код, откроет дверь с первой попытки?

# %%
#Считаем количесво комбинаций
S = math.factorial(10)/(math.factorial(3)*math.factorial((10-3)))
#Попыток одна, одновременное нажатие
P = 1 / S
print(f'Вероятность того, что человек, не знающий код, откроет дверь с первой попытки = {round(P*100,3)}%')
# Out:
# Вероятность того, что человек, не знающий код, откроет дверь с первой попытки = 0.833%

# %%
В ящике имеется 15 деталей, из которых 9 окрашены. 
Рабочий случайным образом извлекает 3 детали. 
Какова вероятность того, что все извлеченные детали окрашены?

# %%
#Поочередно извлекаем детали и перемноджаем вероятности
P = (9/15)*(8/14)*(7/13)
print(f'Вероятность того, что все извлеченные детали окрашены = {round(P*100)}%')
# Out:
# Вероятность того, что все извлеченные детали окрашены = 18%

# %%
В лотерее 100 билетов. Из них 2 выигрышных. 
Какова вероятность того, что 2 приобретенных билета окажутся выигрышными?

# %%
P = (2/100)*(1/99)
print(f'Вероятность того, что 2 приобретенных билета окажутся выигрышными = {round(P*100,3)}%')
# Out:
# Вероятность того, что 2 приобретенных билета окажутся выигрышными = 0.02%
